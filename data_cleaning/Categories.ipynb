# %%
import pandas as pd

# %%
cat = ["cleaned_category_116_frame.csv"
       ,"cleaned_category_18_frame.csv",
       "cleaned_category_20_frame.csv", 
       "cleaned_category_24_frame.csv",
       "cleaned_category_28_frame.csv",
       "cleaned_category_30_frame.csv",
       "cleaned_category_329_frame.csv",
       "cleaned_category_41_frame.csv", 
       "cleaned_category_4322_frame.csv", 
       "cleaned_category_4323_frame.csv", 
       "cleaned_category_4729_frame.csv"]

# %%
for i in range(0, len(cat)):
    df = pd.read_csv(cat[i])
    globals()[f"frame_{i}"] = df

# %%
frame_0["Supermarket"].value_counts()
# Out:
# kaufland     594
# edeka        546
# rewe         288
# lidl         202
# aldi-nord    169
# aldi-sued    130
# Name: Supermarket, dtype: int64

# %%
supermarket = ["kaufland", "edeka", "rewe","lidl","aldi-nord","aldi-sued"]
category_list = ["116","18","20","24","28","30","329","41","4322","4323","4729"]
# 116_kaufland

# %%
for j in range(0,len(cat)):

    for i in supermarket:

        new_frame = frame_0[frame_0["Supermarket"]==i]
        globals()[f"{i}"] = df

# %%
new_frame
# Out:
#      Unnamed: 0                                               Name  Price  \
# 169         169  Sweet Valley Schattenmorellen entsteint, gezuc...   0.79
# 170         170         Gartenkrone Aldi Süd Rote Bete in Scheiben   0.39
# 171         171                            Armada Sardinen Classic   0.59
# 172         172  Sweet Valley Mandarin-Orangen geschält, leicht...   0.69
# 173         173           Armada Thunfisch Filet in Sonnenblumenöl   1.09
# ..          ...                                                ...    ...
# 294         294  Gartenkrone / Aldi Süd Schattenmorellen entste...   0.65
# 295         295  Traditionelle Genüsse Herzhafte Landbockwurst ...   2.99
# 296         296    Traditionelle Genüsse Zwetschgen Fruchtkreation   1.79
# 297         297      Traditionelle Genüsse Marillen Fruchtkreation   1.79
# 298         298               Genuss der Saison gekochte Mettwurst   2.29
#
#           Unit        Packet Size Supermarket   Category  Comparable Price
# ...
