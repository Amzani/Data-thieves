# %%
import pandas as pd

# %%
clean = ["aldinord_aldisued.csv",
        "aldinord_edeka.csv",
        "aldisued_edeka.csv",
        "aldinord_rewe.csv",
        "rewe_lidl.csv"]

# %%
df1 = pd.read_csv(clean[0]) 
df2 = pd.read_csv(clean[1]) 
df3 = pd.read_csv(clean[2]) 
df4 = pd.read_csv(clean[3]) 
df5 = pd.read_csv(clean[4])

# %%
a = df5["Comparable Price_x"].mean()

# %%
b = df5["Comparable Price_y"].mean()

# %%
a - b
# Out:
# 0.02155277518967147

# %%
df5
# Out:
#      Unnamed: 0  Unnamed: 0_x  \
# 0             0             4
# 1             1             5
# 2             2            14
# 3             3            35
# 4             4            38
# ..          ...           ...
# 678         678          5789
# 679         679          5798
# 680         680          6132
# 681         681          6144
# 682         682          6175
#
#                                                   Name  Price_x  \
# 0                                              Nutella     3.79
# 1                                            Coca Cola     0.99
# 2                                   Iglo Fischstäbchen     1.77
# 3                     Lätta Halbfettmargarine Original     0.99
# 4    Iglo Filegro Backfisch Traditioneller Ofen-Bac...     1.88
# ..                                                 ...      ...
# 678                                   Deutsche Zuchini     0.69
# 679                      Dallmayr Prodomo ganze Bohnen     5.29
# ...

# %%
118
# Out:
# 118
