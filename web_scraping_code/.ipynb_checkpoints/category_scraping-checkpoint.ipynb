# %%
## Import libraries

import pandas as pd
import re
import datetime
import requests
import bs4
import selenium 
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.firefox.options import Options

# %% [markdown]
# # 1. Selenium scraping of categories

# %% [markdown]
# ## 1.1. Get category values and plain text

# %%
supermarket_list = ["aldi-nord", "aldi-sued", "edeka", "kaufland", "rewe", "lidl"]

supermarket = supermarket_list[0]
url = f"https://www.supermarktcheck.de/{supermarket}/sortiment"
r = requests.get(url)
soup = bs4.BeautifulSoup(r.content, "html.parser")
d = soup.find_all("div", class_="panel-body")[1].find_all("select", class_="form-control")[1].find_all("option")
d
# Out:
# [<option value="0">Alle</option>,
#  <option value="21">Backwaren</option>,
#  <option value="41">Drogerie</option>,
#  <option value="20">Fleisch Wurst Aufschnitt</option>,
#  <option value="4323">Frische Lebensmittel aus der Kühlung</option>,
#  <option value="4729">Getränke</option>,
#  <option value="116">Konserven</option>,
#  <option value="18">Molkereiprodukte</option>,
#  <option value="28">Müsli, Konfitüre &amp; Kaffee</option>,
#  <option value="4322">Nahrungsmittel</option>,
#  <option value="30">Saucen, Suppen &amp; Gewürze</option>,
#  <option value="329">Süßwaren &amp; Knabberartikel</option>,
#  <option value="24">Tiefkühlkost</option>]

# %%
category_list = []
value_list = []
for i in d:
    category_list.append(i.contents[0])
    stri = str(i.contents[0])
    value = str(i).replace('<option value="',"").replace('">'," ").replace("</option>","")
    value_list.append(value)

digit_pattern = r"^(\d+\w)"
digit_value_list = []
for i in value_list:
    digiz = re.findall(digit_pattern, i)
    digit_value_list.append(digiz)
    
print(category_list, digit_value_list)
# Out:
# ['Alle', 'Backwaren', 'Drogerie', 'Fleisch Wurst Aufschnitt', 'Frische Lebensmittel aus der Kühlung', 'Getränke', 'Konserven', 'Molkereiprodukte', 'Müsli, Konfitüre & Kaffee', 'Nahrungsmittel', 'Saucen, Suppen & Gewürze', 'Süßwaren & Knabberartikel', 'Tiefkühlkost'] [[], ['21'], ['41'], ['20'], ['4323'], ['4729'], ['116'], ['18'], ['28'], ['4322'], ['30'], ['329'], ['24']]

# %%
# Remove the first "all category from both"

category_list = category_list[1:]
digit_value_list = digit_value_list[1:]

# %% [markdown]
# ## Selenium detour

# %%
soup = 0
#options = Options()
#options.add_argument("--headless")
#driver = webdriver.Firefox(options=options)
driver = webdriver.PhantomJS()
driver.get("https://www.supermarktcheck.de/aldi-nord/sortiment/")
select = Select(driver.find_element_by_name('cat_id'))

try:
    select.select_by_value(digit_value_list[1][0])
except:
    driver.execute_script("window.scrollBy(0, 150);")
    print("scrolled at 1")



try:
    submit_button = driver.find_elements_by_class_name("submit")
except:
    driver.execute_script("window.scrollBy(0, 150);")
    print("scrolled at 2")
    
try:
    submit_button[0].click()
except:
    driver.execute_script("window.scrollBy(0, 150);")
    print("scrolled at 3")

html = driver.page_source
driver.close()
soup = bs4.BeautifulSoup(html,"html.parser")
# Out:
# /Users/aswegs/opt/miniconda3/envs/code_red/lib/python3.7/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# scrolled at 1
# scrolled at 3

# %% [markdown]
# # 1. Scraping of categories

# %%
for k in range(0,len(digit_value_list)):
    
    print("product category:", category_list[k])
    
    init_frame = pd.DataFrame(columns=['Name','Price','Price per','Unit','Packet Size','Supermarket','Category'])
    
    for i in range(0,len(supermarket_list)):
    
        j = supermarket_list[i]
        kvalue = digit_value_list[k][0]
        
        result_frame = supermarket_scraper(j,True,kvalue)
        result_frame["Category"] = category_list[k]
        
        frame_list = [init_frame,result_frame]
        init_frame = pd.concat(frame_list)
        
        if "aldi" not in j:
            
            globals()[f'frame_{j}_{kvalue}'] = result_frame
            
        else:
            
            globals()[f'frame_aldi_{i}_{kvalue}'] = result_frame
    
    init_frame.to_csv(f"category_{kvalue}_frame.csv")
    globals()[f"../supermarket_csvs/frame_all_supermarkets_category_{kvalue}"] = init_frame
# Out:
# product category: Backwaren
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 13
# page:  2
# items on page: 14
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 13
# page:  6
# items on page: 14
# page:  7
# items on page: 13
# page:  8
# items on page: 2
# page:  9
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 13
# page:  2
# items on page: 14
# page:  3
# items on page: 13
# page:  4
# items on page: 9
# page:  5
# items on page: 12
# page:  6
# items on page: 13
# page:  7
# items on page: 14
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 4
# page:  11
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 14
# page:  3
# items on page: 13
# page:  4
# items on page: 14
# page:  5
# items on page: 14
# page:  6
# items on page: 8
# page:  7
# items on page: 15
# page:  8
# items on page: 8
# page:  9
# items on page: 10
# page:  10
# items on page: 13
# page:  11
# items on page: 13
# page:  12
# items on page: 8
# page:  13
# items on page: 15
# page:  14
# items on page: 11
# page:  15
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 14
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 13
# page:  8
# items on page: 14
# page:  9
# items on page: 12
# page:  10
# items on page: 14
# page:  11
# items on page: 13
# page:  12
# items on page: 14
# page:  13
# items on page: 15
# page:  14
# items on page: 12
# page:  15
# items on page: 15
# page:  16
# items on page: 12
# page:  17
# Current supermarket:  rewe
# items on page: 14
# page:  1
# items on page: 13
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 14
# page:  5
# items on page: 14
# page:  6
# items on page: 9
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 14
# page:  10
# items on page: 15
# page:  11
# items on page: 10
# page:  12
# items on page: 11
# page:  13
# items on page: 8
# page:  14
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 12
# page:  3
# items on page: 15
# page:  4
# items on page: 13
# page:  5
# items on page: 14
# page:  6
# items on page: 11
# page:  7
# items on page: 10
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 6
# page:  11
# product category: Drogerie
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 11
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 12
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 13
# page:  13
# items on page: 12
# page:  14
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 13
# page:  6
# items on page: 9
# page:  7
# items on page: 11
# page:  8
# items on page: 11
# page:  9
# items on page: 14
# page:  10
# items on page: 13
# page:  11
# items on page: 15
# page:  12
# items on page: 14
# page:  13
# items on page: 15
# page:  14
# items on page: 11
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 12
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 8
# page:  24
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 12
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 14
# page:  10
# items on page: 13
# page:  11
# items on page: 6
# page:  12
# items on page: 14
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 13
# page:  20
# items on page: 13
# page:  21
# items on page: 13
# page:  22
# items on page: 15
# page:  23
# items on page: 5
# page:  24
# items on page: 10
# page:  25
# items on page: 0
# page:  26
# items on page: 0
# page:  27
# items on page: 12
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 15
# page:  44
# items on page: 15
# page:  45
# items on page: 15
# page:  46
# items on page: 15
# page:  47
# items on page: 15
# page:  48
# items on page: 15
# page:  49
# items on page: 15
# page:  50
# items on page: 15
# page:  51
# items on page: 15
# page:  52
# items on page: 15
# page:  53
# items on page: 15
# page:  54
# items on page: 15
# page:  55
# items on page: 15
# page:  56
# items on page: 11
# page:  57
# items on page: 15
# page:  58
# items on page: 15
# page:  59
# items on page: 15
# page:  60
# items on page: 15
# page:  61
# items on page: 15
# page:  62
# items on page: 15
# page:  63
# items on page: 15
# page:  64
# items on page: 15
# page:  65
# items on page: 15
# page:  66
# items on page: 15
# page:  67
# items on page: 15
# page:  68
# items on page: 15
# page:  69
# items on page: 15
# page:  70
# items on page: 15
# page:  71
# items on page: 15
# page:  72
# items on page: 15
# page:  73
# items on page: 15
# page:  74
# items on page: 15
# page:  75
# items on page: 15
# page:  76
# items on page: 15
# page:  77
# items on page: 15
# page:  78
# items on page: 15
# page:  79
# items on page: 12
# page:  80
# items on page: 15
# page:  81
# items on page: 11
# page:  82
# items on page: 8
# page:  83
# items on page: 15
# page:  84
# items on page: 15
# page:  85
# items on page: 14
# page:  86
# items on page: 15
# page:  87
# items on page: 15
# page:  88
# items on page: 15
# page:  89
# items on page: 0
# page:  90
# items on page: 0
# page:  91
# items on page: 0
# page:  92
# items on page: 0
# page:  93
# items on page: 3
# page:  94
# items on page: 15
# page:  95
# items on page: 6
# page:  96
# items on page: 5
# page:  97
# items on page: 15
# page:  98
# items on page: 15
# page:  99
# items on page: 15
# page:  100
# items on page: 15
# page:  101
# items on page: 15
# page:  102
# items on page: 15
# page:  103
# items on page: 15
# page:  104
# items on page: 15
# page:  105
# items on page: 15
# page:  106
# items on page: 15
# page:  107
# items on page: 15
# page:  108
# items on page: 15
# page:  109
# items on page: 15
# page:  110
# items on page: 15
# page:  111
# items on page: 15
# page:  112
# items on page: 15
# page:  113
# items on page: 15
# page:  114
# items on page: 15
# page:  115
# items on page: 15
# page:  116
# items on page: 15
# page:  117
# items on page: 15
# page:  118
# items on page: 15
# page:  119
# items on page: 15
# page:  120
# items on page: 15
# page:  121
# items on page: 15
# page:  122
# items on page: 15
# page:  123
# items on page: 13
# page:  124
# items on page: 10
# page:  125
# items on page: 15
# page:  126
# items on page: 15
# page:  127
# items on page: 15
# page:  128
# items on page: 15
# page:  129
# items on page: 15
# page:  130
# items on page: 15
# page:  131
# items on page: 15
# page:  132
# items on page: 15
# page:  133
# items on page: 15
# page:  134
# items on page: 10
# page:  135
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 14
# page:  5
# items on page: 13
# page:  6
# items on page: 15
# page:  7
# items on page: 14
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 14
# page:  11
# items on page: 12
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 13
# page:  17
# items on page: 15
# page:  18
# items on page: 11
# page:  19
# items on page: 14
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 14
# page:  25
# items on page: 13
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 14
# page:  30
# items on page: 12
# page:  31
# items on page: 14
# page:  32
# items on page: 0
# page:  33
# items on page: 0
# page:  34
# items on page: 0
# page:  35
# items on page: 8
# page:  36
# items on page: 14
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 1
# page:  40
# items on page: 0
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 15
# page:  44
# items on page: 8
# page:  45
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 13
# page:  3
# items on page: 15
# page:  4
# items on page: 13
# page:  5
# items on page: 14
# page:  6
# items on page: 15
# page:  7
# items on page: 14
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 8
# page:  15
# items on page: 10
# page:  16
# items on page: 13
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 8
# page:  24
# items on page: 12
# page:  25
# items on page: 6
# page:  26
# items on page: 0
# page:  27
# items on page: 14
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 9
# page:  34
# items on page: 0
# page:  35
# items on page: 0
# page:  36
# items on page: 0
# page:  37
# items on page: 0
# page:  38
# items on page: 0
# page:  39
# items on page: 0
# page:  40
# items on page: 1
# page:  41
# items on page: 7
# page:  42
# items on page: 14
# page:  43
# items on page: 15
# page:  44
# items on page: 15
# page:  45
# items on page: 15
# page:  46
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 13
# page:  2
# items on page: 12
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 13
# page:  7
# items on page: 12
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 10
# page:  11
# items on page: 15
# page:  12
# items on page: 12
# page:  13
# items on page: 14
# page:  14
# items on page: 13
# page:  15
# items on page: 9
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 14
# page:  19
# items on page: 14
# page:  20
# items on page: 11
# page:  21
# items on page: 14
# page:  22
# items on page: 14
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 13
# page:  26
# items on page: 12
# page:  27
# items on page: 4
# page:  28
# items on page: 0
# page:  29
# items on page: 0
# page:  30
# items on page: 0
# page:  31
# items on page: 13
# page:  32
# items on page: 11
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 14
# page:  37
# items on page: 8
# page:  38
# items on page: 4
# page:  39
# items on page: 0
# page:  40
# items on page: 7
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 13
# page:  44
# items on page: 12
# page:  45
# items on page: 8
# page:  46
# product category: Fleisch Wurst Aufschnitt
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 14
# page:  7
# items on page: 11
# page:  8
# items on page: 14
# page:  9
# items on page: 14
# page:  10
# items on page: 9
# page:  11
# items on page: 15
# page:  12
# items on page: 9
# page:  13
# items on page: 15
# page:  14
# items on page: 11
# page:  15
# items on page: 14
# page:  16
# items on page: 9
# page:  17
# items on page: 9
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 13
# page:  23
# items on page: 15
# page:  24
# items on page: 14
# page:  25
# items on page: 7
# page:  26
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 14
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 11
# page:  6
# items on page: 14
# page:  7
# items on page: 11
# page:  8
# items on page: 14
# page:  9
# items on page: 13
# page:  10
# items on page: 10
# page:  11
# items on page: 13
# page:  12
# items on page: 13
# page:  13
# items on page: 13
# page:  14
# items on page: 15
# page:  15
# items on page: 11
# page:  16
# items on page: 4
# page:  17
# items on page: 12
# page:  18
# items on page: 12
# page:  19
# items on page: 13
# page:  20
# items on page: 15
# page:  21
# items on page: 14
# page:  22
# items on page: 14
# page:  23
# items on page: 7
# page:  24
# items on page: 13
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 12
# page:  29
# items on page: 5
# page:  30
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 15
# page:  4
# items on page: 13
# page:  5
# items on page: 10
# page:  6
# items on page: 15
# page:  7
# items on page: 11
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 13
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 10
# page:  18
# items on page: 13
# page:  19
# items on page: 14
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 13
# page:  24
# items on page: 4
# page:  25
# items on page: 7
# page:  26
# items on page: 14
# page:  27
# items on page: 3
# page:  28
# items on page: 15
# page:  29
# items on page: 1
# page:  30
# items on page: 4
# page:  31
# items on page: 0
# page:  32
# items on page: 7
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 12
# page:  37
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 13
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 15
# page:  7
# items on page: 13
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 10
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 14
# page:  16
# items on page: 15
# page:  17
# items on page: 14
# page:  18
# items on page: 15
# page:  19
# items on page: 13
# page:  20
# items on page: 14
# page:  21
# items on page: 14
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 12
# page:  27
# items on page: 14
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 14
# page:  32
# items on page: 15
# page:  33
# items on page: 14
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 14
# page:  42
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 11
# page:  6
# items on page: 14
# page:  7
# items on page: 15
# page:  8
# items on page: 11
# page:  9
# items on page: 15
# page:  10
# items on page: 14
# page:  11
# items on page: 14
# page:  12
# items on page: 10
# page:  13
# items on page: 14
# page:  14
# items on page: 14
# page:  15
# items on page: 15
# page:  16
# items on page: 12
# page:  17
# items on page: 15
# page:  18
# items on page: 13
# page:  19
# items on page: 13
# page:  20
# items on page: 4
# page:  21
# items on page: 10
# page:  22
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 14
# page:  8
# items on page: 12
# page:  9
# items on page: 10
# page:  10
# items on page: 12
# page:  11
# items on page: 13
# page:  12
# items on page: 15
# page:  13
# items on page: 13
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 4
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 14
# page:  20
# items on page: 12
# page:  21
# items on page: 13
# page:  22
# items on page: 15
# page:  23
# items on page: 13
# page:  24
# items on page: 11
# page:  25
# items on page: 12
# page:  26
# items on page: 12
# page:  27
# items on page: 9
# page:  28
# items on page: 11
# page:  29
# items on page: 14
# page:  30
# items on page: 12
# page:  31
# items on page: 15
# page:  32
# items on page: 10
# page:  33
# items on page: 13
# page:  34
# items on page: 15
# page:  35
# items on page: 14
# page:  36
# items on page: 3
# page:  37
# product category: Frische Lebensmittel aus der Kühlung
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 14
# page:  3
# items on page: 13
# page:  4
# items on page: 15
# page:  5
# items on page: 12
# page:  6
# items on page: 13
# page:  7
# items on page: 13
# page:  8
# items on page: 11
# page:  9
# items on page: 7
# page:  10
# items on page: 13
# page:  11
# items on page: 12
# page:  12
# items on page: 5
# page:  13
# items on page: 11
# page:  14
# items on page: 8
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 14
# page:  18
# items on page: 8
# page:  19
# items on page: 14
# page:  20
# items on page: 1
# page:  21
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 13
# page:  5
# items on page: 13
# page:  6
# items on page: 13
# page:  7
# items on page: 15
# page:  8
# items on page: 13
# page:  9
# items on page: 12
# page:  10
# items on page: 14
# page:  11
# items on page: 15
# page:  12
# items on page: 11
# page:  13
# items on page: 13
# page:  14
# items on page: 14
# page:  15
# items on page: 10
# page:  16
# items on page: 15
# page:  17
# items on page: 13
# page:  18
# items on page: 15
# page:  19
# items on page: 13
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 15
# page:  24
# items on page: 12
# page:  25
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 12
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 11
# page:  8
# items on page: 11
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 11
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 14
# page:  20
# items on page: 10
# page:  21
# items on page: 3
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 14
# page:  27
# items on page: 13
# page:  28
# items on page: 14
# page:  29
# items on page: 15
# page:  30
# items on page: 11
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 8
# page:  34
# items on page: 0
# page:  35
# items on page: 10
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 3
# page:  40
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 12
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 14
# page:  13
# items on page: 14
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 14
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 14
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 13
# page:  25
# items on page: 14
# page:  26
# items on page: 15
# page:  27
# items on page: 14
# page:  28
# items on page: 14
# page:  29
# items on page: 14
# page:  30
# items on page: 14
# page:  31
# items on page: 14
# page:  32
# items on page: 14
# page:  33
# items on page: 14
# page:  34
# items on page: 14
# page:  35
# items on page: 11
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 12
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 6
# page:  42
# Current supermarket:  rewe
# items on page: 14
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 14
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 14
# page:  8
# items on page: 13
# page:  9
# items on page: 13
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 14
# page:  15
# items on page: 15
# page:  16
# items on page: 13
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 14
# page:  21
# items on page: 11
# page:  22
# items on page: 13
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 6
# page:  29
# items on page: 14
# page:  30
# items on page: 15
# page:  31
# items on page: 14
# page:  32
# items on page: 4
# page:  33
# items on page: 10
# page:  34
# items on page: 14
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 0
# page:  38
# items on page: 12
# page:  39
# items on page: 15
# page:  40
# items on page: 14
# page:  41
# items on page: 3
# page:  42
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 11
# page:  5
# items on page: 15
# page:  6
# items on page: 14
# page:  7
# items on page: 13
# page:  8
# items on page: 13
# page:  9
# items on page: 9
# page:  10
# items on page: 13
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 12
# page:  14
# items on page: 11
# page:  15
# items on page: 14
# page:  16
# items on page: 10
# page:  17
# items on page: 14
# page:  18
# items on page: 15
# page:  19
# items on page: 14
# page:  20
# items on page: 11
# page:  21
# items on page: 13
# page:  22
# items on page: 13
# page:  23
# items on page: 15
# page:  24
# items on page: 11
# page:  25
# items on page: 14
# page:  26
# items on page: 12
# page:  27
# items on page: 14
# page:  28
# items on page: 7
# page:  29
# items on page: 15
# page:  30
# items on page: 12
# page:  31
# items on page: 13
# page:  32
# items on page: 14
# page:  33
# items on page: 13
# page:  34
# items on page: 8
# page:  35
# items on page: 12
# page:  36
# items on page: 12
# page:  37
# items on page: 13
# page:  38
# items on page: 1
# page:  39
# product category: Getränke
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 14
# page:  5
# items on page: 15
# page:  6
# items on page: 14
# page:  7
# items on page: 12
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 13
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 12
# page:  15
# items on page: 5
# page:  16
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 14
# page:  7
# items on page: 12
# page:  8
# items on page: 12
# page:  9
# items on page: 14
# page:  10
# items on page: 13
# page:  11
# items on page: 15
# page:  12
# items on page: 14
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 14
# page:  19
# items on page: 15
# page:  20
# items on page: 1
# page:  21
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 13
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 14
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 13
# page:  12
# items on page: 8
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 14
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 9
# page:  20
# items on page: 15
# page:  21
# items on page: 13
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 14
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 10
# page:  40
# items on page: 15
# page:  41
# items on page: 12
# page:  42
# items on page: 15
# page:  43
# items on page: 6
# page:  44
# items on page: 13
# page:  45
# items on page: 15
# page:  46
# items on page: 15
# page:  47
# items on page: 15
# page:  48
# items on page: 15
# page:  49
# items on page: 15
# page:  50
# items on page: 15
# page:  51
# items on page: 15
# page:  52
# items on page: 15
# page:  53
# items on page: 15
# page:  54
# items on page: 15
# page:  55
# items on page: 15
# page:  56
# items on page: 9
# page:  57
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 14
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 13
# page:  19
# items on page: 15
# page:  20
# items on page: 12
# page:  21
# items on page: 14
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 14
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 13
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 14
# page:  40
# items on page: 12
# page:  41
# items on page: 15
# page:  42
# items on page: 13
# page:  43
# items on page: 15
# page:  44
# items on page: 15
# page:  45
# items on page: 15
# page:  46
# items on page: 14
# page:  47
# items on page: 15
# page:  48
# items on page: 15
# page:  49
# items on page: 14
# page:  50
# items on page: 14
# page:  51
# items on page: 14
# page:  52
# items on page: 12
# page:  53
# items on page: 15
# page:  54
# items on page: 15
# page:  55
# items on page: 15
# page:  56
# items on page: 15
# page:  57
# items on page: 15
# page:  58
# items on page: 15
# page:  59
# items on page: 8
# page:  60
# items on page: 15
# page:  61
# items on page: 15
# page:  62
# items on page: 15
# page:  63
# items on page: 15
# page:  64
# items on page: 15
# page:  65
# items on page: 15
# page:  66
# items on page: 7
# page:  67
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 14
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 14
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 14
# page:  17
# items on page: 14
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 11
# page:  33
# items on page: 14
# page:  34
# items on page: 8
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 1
# page:  38
# items on page: 14
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 15
# page:  44
# items on page: 15
# page:  45
# items on page: 15
# page:  46
# items on page: 15
# page:  47
# items on page: 15
# page:  48
# items on page: 8
# page:  49
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 15
# page:  7
# items on page: 14
# page:  8
# items on page: 14
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 13
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 14
# page:  16
# items on page: 14
# page:  17
# items on page: 11
# page:  18
# items on page: 13
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 13
# page:  24
# items on page: 13
# page:  25
# items on page: 8
# page:  26
# items on page: 15
# page:  27
# items on page: 14
# page:  28
# items on page: 13
# page:  29
# items on page: 12
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 5
# page:  33
# product category: Konserven
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 12
# page:  4
# items on page: 8
# page:  5
# items on page: 13
# page:  6
# items on page: 13
# page:  7
# items on page: 14
# page:  8
# items on page: 14
# page:  9
# items on page: 15
# page:  10
# items on page: 14
# page:  11
# items on page: 14
# page:  12
# items on page: 7
# page:  13
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 13
# page:  3
# items on page: 12
# page:  4
# items on page: 12
# page:  5
# items on page: 11
# page:  6
# items on page: 15
# page:  7
# items on page: 12
# page:  8
# items on page: 15
# page:  9
# items on page: 11
# page:  10
# Current supermarket:  edeka
# items on page: 13
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 8
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 7
# page:  8
# items on page: 13
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 11
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 14
# page:  17
# items on page: 10
# page:  18
# items on page: 0
# page:  19
# items on page: 12
# page:  20
# items on page: 15
# page:  21
# items on page: 14
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 14
# page:  25
# items on page: 7
# page:  26
# items on page: 11
# page:  27
# items on page: 2
# page:  28
# items on page: 15
# page:  29
# items on page: 13
# page:  30
# items on page: 15
# page:  31
# items on page: 14
# page:  32
# items on page: 9
# page:  33
# items on page: 11
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 3
# page:  43
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 12
# page:  8
# items on page: 14
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 14
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 13
# page:  21
# items on page: 13
# page:  22
# items on page: 14
# page:  23
# items on page: 14
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 14
# page:  28
# items on page: 15
# page:  29
# items on page: 13
# page:  30
# items on page: 13
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 14
# page:  34
# items on page: 14
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 12
# page:  41
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 10
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 13
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 5
# page:  18
# items on page: 11
# page:  19
# items on page: 10
# page:  20
# items on page: 0
# page:  21
# items on page: 0
# page:  22
# items on page: 12
# page:  23
# items on page: 3
# page:  24
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 13
# page:  5
# items on page: 14
# page:  6
# items on page: 13
# page:  7
# items on page: 13
# page:  8
# items on page: 14
# page:  9
# items on page: 10
# page:  10
# items on page: 9
# page:  11
# items on page: 13
# page:  12
# items on page: 15
# page:  13
# items on page: 14
# page:  14
# items on page: 15
# page:  15
# product category: Molkereiprodukte
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 14
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 11
# page:  10
# items on page: 12
# page:  11
# items on page: 14
# page:  12
# items on page: 13
# page:  13
# items on page: 14
# page:  14
# items on page: 12
# page:  15
# items on page: 9
# page:  16
# items on page: 10
# page:  17
# items on page: 11
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 14
# page:  22
# items on page: 13
# page:  23
# items on page: 15
# page:  24
# items on page: 11
# page:  25
# items on page: 15
# page:  26
# items on page: 13
# page:  27
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 13
# page:  10
# items on page: 14
# page:  11
# items on page: 12
# page:  12
# items on page: 12
# page:  13
# items on page: 15
# page:  14
# items on page: 10
# page:  15
# items on page: 14
# page:  16
# items on page: 14
# page:  17
# items on page: 13
# page:  18
# items on page: 14
# page:  19
# items on page: 14
# page:  20
# items on page: 12
# page:  21
# items on page: 14
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 11
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 14
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 10
# page:  32
# items on page: 0
# page:  33
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 13
# page:  7
# items on page: 11
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 14
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 12
# page:  15
# items on page: 12
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 13
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 14
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 11
# page:  44
# items on page: 10
# page:  45
# items on page: 15
# page:  46
# items on page: 15
# page:  47
# items on page: 15
# page:  48
# items on page: 14
# page:  49
# items on page: 15
# page:  50
# items on page: 15
# page:  51
# items on page: 15
# page:  52
# items on page: 13
# page:  53
# items on page: 12
# page:  54
# items on page: 10
# page:  55
# items on page: 14
# page:  56
# items on page: 10
# page:  57
# items on page: 15
# page:  58
# items on page: 15
# page:  59
# items on page: 10
# page:  60
# items on page: 14
# page:  61
# items on page: 15
# page:  62
# items on page: 15
# page:  63
# items on page: 13
# page:  64
# items on page: 15
# page:  65
# items on page: 6
# page:  66
# items on page: 0
# page:  67
# items on page: 15
# page:  68
# items on page: 15
# page:  69
# items on page: 15
# page:  70
# items on page: 15
# page:  71
# items on page: 15
# page:  72
# items on page: 14
# page:  73
# items on page: 15
# page:  74
# items on page: 15
# page:  75
# items on page: 2
# page:  76
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 13
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 14
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 14
# page:  14
# items on page: 15
# page:  15
# items on page: 14
# page:  16
# items on page: 13
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 14
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 9
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 14
# page:  32
# items on page: 14
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 13
# page:  44
# items on page: 13
# page:  45
# items on page: 15
# page:  46
# items on page: 15
# page:  47
# items on page: 15
# page:  48
# items on page: 14
# page:  49
# items on page: 13
# page:  50
# items on page: 15
# page:  51
# items on page: 15
# page:  52
# items on page: 15
# page:  53
# items on page: 15
# page:  54
# items on page: 15
# page:  55
# items on page: 14
# page:  56
# items on page: 14
# page:  57
# items on page: 13
# page:  58
# items on page: 15
# page:  59
# items on page: 15
# page:  60
# items on page: 13
# page:  61
# items on page: 15
# page:  62
# items on page: 13
# page:  63
# items on page: 15
# page:  64
# items on page: 15
# page:  65
# items on page: 14
# page:  66
# items on page: 1
# page:  67
# items on page: 15
# page:  68
# items on page: 15
# page:  69
# items on page: 15
# page:  70
# items on page: 15
# page:  71
# items on page: 5
# page:  72
# items on page: 15
# page:  73
# items on page: 15
# page:  74
# items on page: 12
# page:  75
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 13
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 12
# page:  10
# items on page: 13
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 14
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 13
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 14
# page:  26
# items on page: 15
# page:  27
# items on page: 13
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 10
# page:  32
# items on page: 14
# page:  33
# items on page: 14
# page:  34
# items on page: 14
# page:  35
# items on page: 15
# page:  36
# items on page: 14
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 14
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 15
# page:  44
# items on page: 14
# page:  45
# items on page: 13
# page:  46
# items on page: 15
# page:  47
# items on page: 15
# page:  48
# items on page: 15
# page:  49
# items on page: 1
# page:  50
# items on page: 12
# page:  51
# items on page: 15
# page:  52
# items on page: 15
# page:  53
# items on page: 13
# page:  54
# items on page: 0
# page:  55
# items on page: 0
# page:  56
# items on page: 15
# page:  57
# items on page: 15
# page:  58
# items on page: 15
# page:  59
# items on page: 8
# page:  60
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 14
# page:  14
# items on page: 14
# page:  15
# items on page: 13
# page:  16
# items on page: 14
# page:  17
# items on page: 8
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 11
# page:  26
# items on page: 5
# page:  27
# items on page: 15
# page:  28
# items on page: 14
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 12
# page:  34
# items on page: 15
# page:  35
# items on page: 10
# page:  36
# items on page: 13
# page:  37
# items on page: 15
# page:  38
# items on page: 14
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 14
# page:  42
# items on page: 11
# page:  43
# items on page: 15
# page:  44
# items on page: 12
# page:  45
# items on page: 14
# page:  46
# items on page: 8
# page:  47
# items on page: 14
# page:  48
# items on page: 11
# page:  49
# items on page: 13
# page:  50
# items on page: 13
# page:  51
# items on page: 15
# page:  52
# items on page: 10
# page:  53
# items on page: 14
# page:  54
# items on page: 15
# page:  55
# items on page: 8
# page:  56
# items on page: 14
# page:  57
# items on page: 15
# page:  58
# items on page: 14
# page:  59
# items on page: 9
# page:  60
# items on page: 14
# page:  61
# items on page: 7
# page:  62
# product category: Müsli, Konfitüre & Kaffee
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 14
# page:  7
# items on page: 12
# page:  8
# items on page: 12
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 5
# page:  13
# items on page: 5
# page:  14
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 14
# page:  5
# items on page: 15
# page:  6
# items on page: 13
# page:  7
# items on page: 14
# page:  8
# items on page: 11
# page:  9
# items on page: 13
# page:  10
# items on page: 13
# page:  11
# items on page: 13
# page:  12
# items on page: 13
# page:  13
# items on page: 12
# page:  14
# items on page: 12
# page:  15
# items on page: 12
# page:  16
# items on page: 6
# page:  17
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 11
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 14
# page:  9
# items on page: 15
# page:  10
# items on page: 11
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 14
# page:  17
# items on page: 15
# page:  18
# items on page: 13
# page:  19
# items on page: 13
# page:  20
# items on page: 14
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 13
# page:  30
# items on page: 12
# page:  31
# items on page: 12
# page:  32
# items on page: 15
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 14
# page:  38
# items on page: 13
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 15
# page:  44
# items on page: 15
# page:  45
# items on page: 14
# page:  46
# items on page: 13
# page:  47
# items on page: 15
# page:  48
# items on page: 9
# page:  49
# items on page: 15
# page:  50
# items on page: 15
# page:  51
# items on page: 15
# page:  52
# items on page: 15
# page:  53
# items on page: 15
# page:  54
# items on page: 15
# page:  55
# items on page: 15
# page:  56
# items on page: 15
# page:  57
# items on page: 15
# page:  58
# items on page: 15
# page:  59
# items on page: 6
# page:  60
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 14
# page:  14
# items on page: 14
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 15
# page:  24
# items on page: 13
# page:  25
# items on page: 15
# page:  26
# items on page: 14
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 14
# page:  38
# items on page: 14
# page:  39
# items on page: 14
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 15
# page:  44
# items on page: 14
# page:  45
# items on page: 15
# page:  46
# items on page: 8
# page:  47
# items on page: 15
# page:  48
# items on page: 14
# page:  49
# items on page: 13
# page:  50
# items on page: 13
# page:  51
# items on page: 11
# page:  52
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 13
# page:  9
# items on page: 12
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 14
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# ...
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 12
# page:  23
# items on page: 6
# page:  24
# items on page: 14
# page:  25
# items on page: 15
# page:  26
# items on page: 4
# page:  27
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 13
# page:  2
# items on page: 15
# page:  3
# items on page: 5
# page:  4
# items on page: 13
# page:  5
# items on page: 13
# page:  6
# items on page: 10
# page:  7
# items on page: 14
# page:  8
# items on page: 13
# page:  9
# items on page: 12
# page:  10
# items on page: 12
# page:  11
# items on page: 11
# page:  12
# items on page: 10
# page:  13
# items on page: 10
# page:  14
# items on page: 7
# page:  15
# items on page: 14
# page:  16
# items on page: 14
# page:  17
# items on page: 15
# page:  18
# items on page: 1
# page:  19
# items on page: 7
# page:  20
# items on page: 14
# page:  21
# items on page: 9
# page:  22
# items on page: 13
# page:  23
# items on page: 4
# page:  24
# product category: Süßwaren & Knabberartikel
# Current supermarket:  aldi-nord
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 14
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 12
# page:  8
# items on page: 14
# page:  9
# items on page: 14
# page:  10
# items on page: 13
# page:  11
# items on page: 11
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 9
# page:  15
# items on page: 10
# page:  16
# items on page: 10
# page:  17
# items on page: 10
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 13
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 10
# page:  25
# items on page: 15
# page:  26
# items on page: 14
# page:  27
# items on page: 15
# page:  28
# items on page: 14
# page:  29
# items on page: 15
# page:  30
# items on page: 2
# page:  31
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 13
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 13
# page:  7
# items on page: 15
# page:  8
# items on page: 14
# page:  9
# items on page: 15
# page:  10
# items on page: 14
# page:  11
# items on page: 15
# page:  12
# items on page: 7
# page:  13
# items on page: 13
# page:  14
# items on page: 12
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 13
# page:  18
# items on page: 14
# page:  19
# items on page: 15
# page:  20
# items on page: 12
# page:  21
# items on page: 13
# page:  22
# items on page: 11
# page:  23
# items on page: 14
# page:  24
# items on page: 14
# page:  25
# items on page: 14
# page:  26
# items on page: 15
# page:  27
# items on page: 13
# page:  28
# items on page: 10
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 14
# page:  32
# items on page: 14
# page:  33
# items on page: 15
# page:  34
# items on page: 4
# page:  35
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 13
# page:  5
# items on page: 10
# page:  6
# items on page: 14
# page:  7
# items on page: 15
# page:  8
# items on page: 13
# page:  9
# items on page: 15
# page:  10
# items on page: 8
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 14
# page:  18
# items on page: 14
# page:  19
# items on page: 14
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 14
# page:  26
# items on page: 14
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 8
# page:  30
# items on page: 10
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 15
# page:  34
# items on page: 15
# page:  35
# items on page: 15
# page:  36
# items on page: 15
# page:  37
# items on page: 13
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 15
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 14
# page:  44
# items on page: 15
# page:  45
# items on page: 9
# page:  46
# items on page: 7
# page:  47
# items on page: 15
# page:  48
# items on page: 6
# page:  49
# items on page: 14
# page:  50
# items on page: 13
# page:  51
# items on page: 15
# page:  52
# items on page: 12
# page:  53
# items on page: 0
# page:  54
# items on page: 11
# page:  55
# items on page: 15
# page:  56
# items on page: 15
# page:  57
# items on page: 15
# page:  58
# items on page: 15
# page:  59
# items on page: 15
# page:  60
# items on page: 15
# page:  61
# items on page: 15
# page:  62
# items on page: 15
# page:  63
# items on page: 15
# page:  64
# items on page: 15
# page:  65
# items on page: 15
# page:  66
# items on page: 14
# page:  67
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 14
# page:  10
# items on page: 15
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 14
# page:  20
# items on page: 13
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 14
# page:  27
# items on page: 14
# page:  28
# items on page: 14
# page:  29
# items on page: 14
# page:  30
# items on page: 15
# page:  31
# items on page: 14
# page:  32
# items on page: 14
# page:  33
# items on page: 12
# page:  34
# items on page: 15
# page:  35
# items on page: 14
# page:  36
# items on page: 14
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 6
# page:  41
# items on page: 14
# page:  42
# items on page: 8
# page:  43
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 15
# page:  7
# items on page: 13
# page:  8
# items on page: 15
# page:  9
# items on page: 15
# page:  10
# items on page: 14
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 14
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 14
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 12
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 13
# page:  30
# items on page: 12
# page:  31
# items on page: 14
# page:  32
# items on page: 15
# page:  33
# items on page: 15
# page:  34
# items on page: 4
# page:  35
# items on page: 0
# page:  36
# items on page: 12
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 13
# page:  40
# items on page: 14
# page:  41
# items on page: 3
# page:  42
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 15
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 14
# page:  10
# items on page: 14
# page:  11
# items on page: 15
# page:  12
# items on page: 10
# page:  13
# items on page: 14
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 12
# page:  17
# items on page: 12
# page:  18
# items on page: 10
# page:  19
# items on page: 12
# page:  20
# items on page: 15
# page:  21
# items on page: 5
# page:  22
# items on page: 14
# page:  23
# items on page: 14
# page:  24
# items on page: 13
# page:  25
# items on page: 11
# page:  26
# items on page: 11
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 14
# page:  30
# items on page: 14
# page:  31
# items on page: 10
# page:  32
# items on page: 13
# page:  33
# items on page: 12
# page:  34
# items on page: 13
# page:  35
# items on page: 11
# page:  36
# items on page: 15
# page:  37
# items on page: 14
# page:  38
# items on page: 13
# page:  39
# items on page: 15
# page:  40
# items on page: 13
# page:  41
# items on page: 0
# page:  42
# items on page: 15
# page:  43
# items on page: 14
# page:  44
# items on page: 10
# page:  45
# items on page: 1
# page:  46
# items on page: 11
# page:  47
# items on page: 14
# page:  48
# product category: Tiefkühlkost
# Current supermarket:  aldi-nord
# items on page: 14
# page:  1
# items on page: 14
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 13
# page:  5
# items on page: 14
# page:  6
# items on page: 13
# page:  7
# items on page: 11
# page:  8
# items on page: 8
# page:  9
# items on page: 14
# page:  10
# items on page: 15
# page:  11
# items on page: 7
# page:  12
# items on page: 13
# page:  13
# items on page: 15
# page:  14
# items on page: 0
# page:  15
# items on page: 10
# page:  16
# items on page: 15
# page:  17
# items on page: 15
# page:  18
# items on page: 14
# page:  19
# items on page: 15
# page:  20
# items on page: 14
# page:  21
# items on page: 15
# page:  22
# items on page: 15
# page:  23
# items on page: 15
# page:  24
# items on page: 9
# page:  25
# items on page: 1
# page:  26
# Current supermarket:  aldi-sued
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 14
# page:  3
# items on page: 15
# page:  4
# items on page: 12
# page:  5
# items on page: 12
# page:  6
# items on page: 14
# page:  7
# items on page: 11
# page:  8
# items on page: 14
# page:  9
# items on page: 12
# page:  10
# items on page: 8
# page:  11
# items on page: 15
# page:  12
# items on page: 15
# page:  13
# items on page: 10
# page:  14
# items on page: 13
# page:  15
# items on page: 10
# page:  16
# items on page: 12
# page:  17
# items on page: 9
# page:  18
# items on page: 15
# page:  19
# items on page: 14
# page:  20
# items on page: 15
# page:  21
# items on page: 12
# page:  22
# items on page: 15
# page:  23
# items on page: 13
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 15
# page:  28
# items on page: 15
# page:  29
# items on page: 4
# page:  30
# Current supermarket:  edeka
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 13
# page:  3
# items on page: 14
# page:  4
# items on page: 15
# page:  5
# items on page: 14
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 14
# page:  9
# items on page: 14
# page:  10
# items on page: 6
# page:  11
# items on page: 14
# page:  12
# items on page: 14
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 14
# page:  16
# items on page: 7
# page:  17
# items on page: 15
# page:  18
# items on page: 14
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 12
# page:  24
# items on page: 13
# page:  25
# items on page: 12
# page:  26
# items on page: 5
# page:  27
# items on page: 14
# page:  28
# items on page: 15
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 13
# page:  34
# items on page: 8
# page:  35
# items on page: 0
# page:  36
# items on page: 4
# page:  37
# items on page: 15
# page:  38
# items on page: 15
# page:  39
# items on page: 15
# page:  40
# items on page: 14
# page:  41
# items on page: 15
# page:  42
# items on page: 15
# page:  43
# items on page: 14
# page:  44
# items on page: 15
# page:  45
# items on page: 15
# page:  46
# items on page: 14
# page:  47
# items on page: 7
# page:  48
# items on page: 15
# page:  49
# items on page: 6
# page:  50
# items on page: 13
# page:  51
# items on page: 14
# page:  52
# items on page: 0
# page:  53
# items on page: 6
# page:  54
# items on page: 15
# page:  55
# items on page: 14
# page:  56
# items on page: 7
# page:  57
# items on page: 0
# page:  58
# items on page: 13
# page:  59
# items on page: 15
# page:  60
# items on page: 14
# page:  61
# items on page: 15
# page:  62
# items on page: 10
# page:  63
# Current supermarket:  kaufland
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 14
# page:  5
# items on page: 15
# page:  6
# items on page: 14
# page:  7
# items on page: 15
# page:  8
# items on page: 15
# page:  9
# items on page: 13
# page:  10
# items on page: 15
# page:  11
# items on page: 11
# page:  12
# items on page: 14
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 15
# page:  17
# items on page: 12
# page:  18
# items on page: 14
# page:  19
# items on page: 11
# page:  20
# items on page: 11
# page:  21
# items on page: 15
# page:  22
# items on page: 14
# page:  23
# items on page: 15
# page:  24
# items on page: 15
# page:  25
# items on page: 11
# page:  26
# items on page: 10
# page:  27
# items on page: 9
# page:  28
# items on page: 14
# page:  29
# items on page: 15
# page:  30
# items on page: 15
# page:  31
# items on page: 15
# page:  32
# items on page: 8
# page:  33
# items on page: 12
# page:  34
# items on page: 9
# page:  35
# items on page: 12
# page:  36
# items on page: 15
# page:  37
# items on page: 14
# page:  38
# items on page: 12
# page:  39
# items on page: 10
# page:  40
# items on page: 10
# page:  41
# items on page: 12
# page:  42
# items on page: 10
# page:  43
# items on page: 14
# page:  44
# items on page: 14
# page:  45
# items on page: 14
# page:  46
# items on page: 13
# page:  47
# items on page: 15
# page:  48
# items on page: 12
# page:  49
# items on page: 15
# page:  50
# items on page: 15
# page:  51
# items on page: 15
# page:  52
# items on page: 12
# page:  53
# items on page: 15
# page:  54
# items on page: 14
# page:  55
# items on page: 10
# page:  56
# Current supermarket:  rewe
# items on page: 15
# page:  1
# items on page: 15
# page:  2
# items on page: 15
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 12
# page:  6
# items on page: 15
# page:  7
# items on page: 15
# page:  8
# items on page: 13
# page:  9
# items on page: 13
# page:  10
# items on page: 15
# page:  11
# items on page: 14
# page:  12
# items on page: 14
# page:  13
# items on page: 15
# page:  14
# items on page: 15
# page:  15
# items on page: 15
# page:  16
# items on page: 14
# page:  17
# items on page: 15
# page:  18
# items on page: 15
# page:  19
# items on page: 15
# page:  20
# items on page: 15
# page:  21
# items on page: 15
# page:  22
# items on page: 5
# page:  23
# items on page: 10
# page:  24
# items on page: 15
# page:  25
# items on page: 15
# page:  26
# items on page: 15
# page:  27
# items on page: 10
# page:  28
# items on page: 14
# page:  29
# items on page: 15
# page:  30
# items on page: 14
# page:  31
# items on page: 15
# page:  32
# items on page: 15
# page:  33
# items on page: 9
# page:  34
# items on page: 15
# page:  35
# items on page: 14
# page:  36
# items on page: 15
# page:  37
# items on page: 6
# page:  38
# items on page: 0
# page:  39
# items on page: 12
# page:  40
# items on page: 15
# page:  41
# items on page: 9
# page:  42
# Current supermarket:  lidl
# items on page: 15
# page:  1
# items on page: 14
# page:  2
# items on page: 14
# page:  3
# items on page: 15
# page:  4
# items on page: 15
# page:  5
# items on page: 13
# page:  6
# items on page: 11
# page:  7
# items on page: 14
# page:  8
# items on page: 15
# page:  9
# items on page: 12
# page:  10
# items on page: 14
# page:  11
# items on page: 12
# page:  12
# items on page: 15
# page:  13
# items on page: 15
# page:  14
# items on page: 14
# page:  15
# items on page: 10
# page:  16
# items on page: 14
# page:  17
# items on page: 13
# page:  18
# items on page: 13
# page:  19
# items on page: 6
# page:  20
# items on page: 15
# page:  21
# items on page: 14
# page:  22
# items on page: 15
# page:  23
# items on page: 12
# page:  24
# items on page: 5
# page:  25
# items on page: 5
# page:  26
# items on page: 9
# page:  27
# items on page: 9
# page:  28
# items on page: 10
# page:  29
# items on page: 13
# page:  30
# items on page: 13
# page:  31
# items on page: 13
# page:  32
# items on page: 0
# page:  33
# items on page: 9
# page:  34
# items on page: 10
# page:  35
# items on page: 15
# page:  36
# items on page: 13
# page:  37
# items on page: 13
# page:  38
# items on page: 14
# page:  39
# items on page: 15
# page:  40
# items on page: 11
# page:  41
# items on page: 15
# page:  42
# items on page: 13
# page:  43
# items on page: 15
# page:  44
# items on page: 13
# page:  45
# items on page: 5
# page:  46
# items on page: 12
# page:  47

# %%
frame_all_supermarkets_category_21.to_csv("csv.csv")

# %%
frame_all_supermarkets_category_21
# Out:
#                                                  Name   Price Price per  \
# 0                  Goldähren Butter Toast geschnitten  0,69 €    1,38 €
# 1             Gut Bio Finnkorn Vollkorn-Toastbrötchen  0,99 €    0,38 €
# 2                            Goldähren Dreikorn Toast  0,59 €    1,18 €
# 3               Goldähren Bauernschnitten geschnitten  0,59 €    1,18 €
# 4   Goldähren Steinofen Baguette Original französisch  0,99 €    0,40 €
# ..                                                ...     ...       ...
# 24  Grafschafter Unsere Besten 6 Bauernbrötchen zu...  0,79 €    0,22 €
# 25                       MC Ennedy Big Sandwich Toast  0,72 €    0,96 €
# 26                              Wasa Knäckebrot Sesam  0,89 €    0,45 €
# 27                 Maitre Brioche Zopf Hefefeingebäck  1,99 €    2,84 €
# 28                             McEnnedy Bagels 5 Korn  0,99 €    0,37 €
#
#                    Unit          Packet Size Supermarket   Category
# 0        Preis pro 1 KG   (Beutel 500 Gramm)   aldi-nord  Backwaren
# 1   Preis pro 100 Gramm  (Packung 260 Gramm)   aldi-nord  Backwaren
# 2        Preis pro 1 KG   (Beutel 500 Gramm)   aldi-nord  Backwaren
# 3        Preis pro 1 KG   (Beutel 500 Gramm)   aldi-nord  Backwaren
# 4   Preis pro 100 Gramm   (Beutel 250 Gramm)   aldi-nord  Backwaren
# ..                  ...                  ...         ...        ...
# 24  Preis pro 100 Gramm   (Beutel 360 Gramm)        lidl  Backwaren
# 25       Preis pro 1 KG  (Packung 750 Gramm)        lidl  Backwaren
# 26  Preis pro 100 Gramm  (Packung 200 Gramm)        lidl  Backwaren
# 27       Preis pro 1 KG  (Packung 700 Gramm)        lidl  Backwaren
# 28  Preis pro 100 Gramm  (Packung 270 Gramm)        lidl  Backwaren
#
# [171 rows x 7 columns]

# %% [markdown]
# # 2. Old code to get the csvs

# %%
## Create a outer for loop for multiple supermarkets.

supermarket_list = ["aldi-nord", "aldi-sued", "edeka", "kaufland", "rewe", "lidl"]

for i in range(0,len(supermarket_list)):
    
    j = supermarket_list[i]
    
    result_frame = supermarket_scraper(j,True)
    
    if "aldi" not in j:
        
        globals()['frame_%s' % j] = result_frame
        
    else:
        
        globals()['frame_aldi_%s' % i] = result_frame
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-316-41d52aa91d35> in <module>
#       7     j = supermarket_list[i]
#       8
# ----> 9     result_frame = supermarket_scraper(j,True)
#      10
#      11     if "aldi" not in j:
#
# TypeError: supermarket_scraper() missing 1 required positional argument: 'category_input'

# %%
# As a function


def supermarket_scraper(supermarket_input,print_input,category_input):

    ## Scrape supermarket products

    # Initialize empty framelist for dataframe and set supermarket
    
    frame_list = []
    supermarket = supermarket_input
    prints = print_input
    
    if prints:
        print("Current supermarket: ", supermarket)
    # Check how many pages for this supermarket
    
    pageno = 2
    base = "https://www.supermarktcheck.de/"
    url = base + f"{supermarket}/produkte/page:{pageno}/cat_id:{category_input}"
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.content, "html.parser")
    pages = str(soup.find("div", class_="col-sm-6 text-center btn-pagination-title").contents).replace("\\t","").replace("\\nSeite ","".replace("\[",""))
    pattern = r"[2 von ](\d+)"
    pagenumbers = int(re.findall(pattern,pages)[0])
    
    
        # Iterate through all pages for the supermarket #pagenumbers+1
        
    for j in range(1, pagenumbers+1):
        
        # Scrape soup for each page
        
        supermarket = supermarket_input
        pageno = j
        base = "https://www.supermarktcheck.de/"
        url = base + f"{supermarket}/produkte/page:{pageno}/cat_id:{category_input}"
        r = requests.get(url)
        soup = bs4.BeautifulSoup(r.content, "html.parser")
        
        
        # Get a list of products per page
        
        product_list = soup.find("div", class_="col-sm-8 col-md-9").find_all("div", "supermarketListElement")
        
        
        # List of items per page
        
        item_names = soup.find_all("a", class_="supermarket")
        
        
        # Count how many items per page excluding empty items
        
        counter = 0
        for i in product_list:
            try:
                whatever = i.find("div", class_="col-md-5 col-lg-5").find("strong")
                counter += 1
            except:
                next
                
                
        if prints:
            print("items on page:",counter)
        
        
        # For loop for all products on one page
        
        for i in range(0,counter):
            
            # Initialize a list as empty dataframe row
            
            frame_element = []
            
            
            # Get the item names
            
            supermarket_list = item_names[i].contents[0]
            frame_element.append(supermarket_list)


            # Get the item prices

            price = soup.find_all("div", class_="col-md-5 col-lg-5")
            price = price[i].p.strong.contents[0]
            frame_element.append(price)


            # Get price per unit and unit

            price_per = soup.find_all("div", class_="col-md-5 col-lg-5")
            price_per_item_price = price_per[i].span.contents[0]
            price_per_item_i = price_per[i].small.contents[0]
            frame_element.append(price_per_item_price)
            frame_element.append(price_per_item_i)


            # Get the packet size

            packet_size = soup.find_all("div", class_="col-md-7 col-lg-7")
            packet_size = packet_size[i].find_all("p")[1].contents[0]
            frame_element.append(packet_size)


            # Append the list to the frame list

            frame_list.append(frame_element)

        if prints:
            print("page: ", j)
        
    # Transform the frame list into a dataframe
    
    frame = pd.DataFrame(frame_list,columns=["Name","Price","Price per", "Unit", "Packet Size"])
    frame["Supermarket"] = supermarket
    frame["Category"] = category_input
    
    return frame
