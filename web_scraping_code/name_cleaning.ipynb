# %%
## Import libraries

import pandas as pd
import re
import datetime
import requests
import bs4

# %%
df = pd.read_csv("../supermarket_csvs/aldi_products.csv")

# %%
for i in list(df["Name"].value_counts().index):
    print(i.split(" "))
# Out:
# ['T', 'Amoro', '/', 'Aldi', 'Nord', 'Profiteroles']
# ['Elbflorenz', 'Edle', 'Obstbrände', 'in', 'zarter', 'Kruste']
# ['Mama', 'Mancini', 'Lasagne', 'Bolognese']
# ['Biscotto', 'Florenz']
# ['Bäckerbrötchen']
# ['Hofburger', 'Weichkäse', 'Passion', 'Bunter', 'Pfeffermix']
# ['Golden', 'Seafood', 'Norwegisches', 'Lachsfilet']
# ['Medion', 'Aldi', 'Nord', 'CD', 'Rohlinge', 'CD-R', '80']
# ['Aldi', 'Nord', 'Kaffeeweißer']
# ['Landbeck', '/', 'Aldi', 'Nord', 'Wiener', 'Würstchen']
# ['Biscotto', 'Kaffee', 'Gebäck']
# ['River', 'Eistee', 'Zitrone']
# ['River', 'Cola', 'Mix']
# ['Tremondi', 'Prosciutto', 'luftgetrocknet']
# ['Chateau', 'Schokoriegel', 'Nuss', '&', 'Crisp']
# ['Goldähren', 'Eiweißbrot']
# ['Sprengel', 'Adventskalender', '2012']
# ['Casale', 'Parmigiano', 'Reggiano']
# ['Freihofer', 'Gourmet', 'Burgunder', 'Sauce']
# ['Oster', 'Phantasie', 'Präsent', 'Ei']
# ['River', 'Eistee', 'Pfirsich']
# ['Freihofer', 'Gourmet', 'Sauce', 'a', 'l', 'Orange']
# ...

# %%
brand_list = "Aldi Nord,Mama Mancini,Hofburger,Golden Seafood,Medion,Landbeck,Biscotto,River,Chateau,Goldähren,Sprengel,Casale,Freihofer,Oster Phantasie,Albona,Pottkiefer,Pure Fruit,Trader Joes, Espana, Butella,Chateau,la finesse, Choceur, Fruchtoase, Freihofer, REichsgraf, Knixx, Ombra Sun Care, Cucina, Schneekoppe, Greece, Delikato, Sprengel, All Seasons, Wies Gart, Sternberger Pfanntastico, Conradl Mon Cafe, Bauernvesper, Casa Morando, Storck, Meine Metzgerei, Gut Bio, Mucci, Ofterdinger, Bel Royal, Milsani, Mein Veggie Tag"
